# %%
import random
#Untuk memulai bermain
def mulai():
    ab = str(input('Apakah anda ingin bermain? (Y/N) : \n'))
    if ab == ('Y'):
        return True
    else:
        return False
#Untuk membuat list yang berisi nomor asal
def number_generator():
    a = []
    for i in range(4):
        a.append(random.randint(1,9))
    return a
#Menanyakan angka
def hasil_tebakan():
    cd = []
    for i in range (4):
        cd.append(int(input('Silahkan tebak angka keberuntungan anda ')))
    return cd
#Untuk Mengecek angka apakah input sama dengan
#Masih bingung disini
def perbandingan (ab, cd):
    dummy_tebakan = set(ab)
    dummy_random = set(cd)
    counter = 0
    cow = 0
    bull = 0
    for i in cd:
        if i == ab[counter]:
            cow+=1
        counter+=1
    for i in dummy_tebakan:
        for c in dummy_random:
            if i == c:
                bull+=1
    return print('Cow = ',cow,', Bull = ',bull)
#untuk menanyakan permainanan ketika permainan telah usai
def new_game():
    ab = str(input('Apakah anda ingin bermain lagi? (Y/N) : \n'))
    if ab == 'Y':
        return True
    else:
        return False

looping = mulai()
while looping:
    hasil_random = number_generator()
    while looping:
        tebakan = hasil_tebakan()
        perbandingan(tebakan,hasil_random)
        if tebakan == hasil_random:
            looping = False
        else:
            print('Anda Salah')
            print(hasil_random)
    looping = new_game()
print(list_number)
# Out:
# Apakah anda ingin bermain? (Y/N) :
# Y
# Silahkan tebak angka keberuntungan anda 1
# Silahkan tebak angka keberuntungan anda 2
# Silahkan tebak angka keberuntungan anda 3
# Silahkan tebak angka keberuntungan anda 4
# Cow =  0 , Bull =  1
# Anda Salah
# [4, 7, 6, 8]
# Silahkan tebak angka keberuntungan anda 6
# Silahkan tebak angka keberuntungan anda 7
# Silahkan tebak angka keberuntungan anda 8
# Silahkan tebak angka keberuntungan anda 4
# Cow =  1 , Bull =  4
# Anda Salah
# [4, 7, 6, 8]
# Silahkan tebak angka keberuntungan anda 6
# Silahkan tebak angka keberuntungan anda 7
# Silahkan tebak angka keberuntungan anda 8
# Silahkan tebak angka keberuntungan anda 8
# Cow =  2 , Bull =  3
# Anda Salah
# [4, 7, 6, 8]
# Silahkan tebak angka keberuntungan anda 1
# Silahkan tebak angka keberuntungan anda 7
# Silahkan tebak angka keberuntungan anda 8
# Silahkan tebak angka keberuntungan anda 8
# Cow =  2 , Bull =  2
# Anda Salah
# [4, 7, 6, 8]
# Silahkan tebak angka keberuntungan anda 2
# ...
